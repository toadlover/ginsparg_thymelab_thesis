# %%
#initial import of relevant packages for graphing
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import ScalarFormatter
from matplotlib.ticker import FuncFormatter
#https://stackoverflow.com/questions/32085531/importing-a-csv-file-into-python-to-make-scatterplots-and-histograms

# %%
#read in the data csv
df = pd.read_csv("../../../benchmarking_other_papers/papers/Synthon-based_ligand_discovery_in_virtual_libraries_of_over_11_billion_compounds/analysis_space/paper_ligands_rank.csv")
df
# Out:
#         ligand  ddg_rank  ddg_percentile  interaction_rank  \
# 0  Z4121492004       364        0.131932               229
# 1  Z4121492147       609        0.220732               565
# 2  Z4886816179       609        0.220732                98
# 3  Z4121492020       609        0.220732              1244
# 4  Z1893460093       609        0.220732               565
# 5  Z4886816121       609        0.220732               565
# 6  Z4121493648       609        0.220732              2681
#
#    interaction_percentile  real_motif_count_rank  real_motif_count_percentile  \
# 0                0.083001                   1025                     0.371511
# 1                0.204784                   1025                     0.371511
# 2                0.035520                   1025                     0.371511
# 3                0.450888                   1025                     0.371511
# 4                0.204784                    267                     0.096774
# 5                0.204784                   1025                     0.371511
# 6                0.971729                   1025                     0.371511
#
#    real_motif_ratio_rank  real_motif_ratio_percentile  Unnamed: 9
# 0                   2611                     0.946357         NaN
# 1                   2611                     0.946357         NaN
# 2                   2611                     0.946357         NaN
# 3                   2611                     0.946357         NaN
# 4                   2611                     0.946357         NaN
# 5                   2611                     0.946357         NaN
# 6                   2611                     0.946357         NaN

# %%
#convert percentiles into percents
df['ddg_percentile'] = (1 - df['ddg_percentile']) * 100
df['interaction_percentile'] = (1 - df['interaction_percentile']) * 100
df['real_motif_count_percentile'] = (1 - df['real_motif_count_percentile']) * 100
df['real_motif_ratio_rank'] = (1 - df['real_motif_ratio_rank']) * 100

# %%
# Create a bar plot for ddg
plt.bar(df['ligand'], df['ddg_percentile'])
plt.xlabel('Paper Ligand')
plt.ylabel('Percentile Ranking Against Control Set')
plt.title('Paper Ligands Percentil Ranking: ddG')

plt.ylim(0,100)

# Set y-axis to display in scientific notation with individual tick values
plt.gca().yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
plt.gca().yaxis.get_major_formatter().set_scientific(False)
plt.gca().yaxis.get_major_formatter().set_powerlimits((0,0))

# Rotate x-axis labels by 45 degrees
plt.xticks(rotation=90)

# Set y-axis to display numbers with commas
plt.gca().yaxis.set_major_formatter(FuncFormatter(lambda x, _: f'{int(x):,}'))

#add note for the text
#plt.text(3, 1, "Conformers: " + str(total_ligands), fontsize=12, color='black')
#plt.annotate("Total Atoms = " + str(total_atoms), xy=(0.29, -0.18), xycoords='axes fraction', fontsize=9, color='black')

plt.show()

# %%
# Create a bar plot for interaction count
plt.bar(df['ligand'], df['interaction_percentile'])
plt.xlabel('Paper Ligand')
plt.ylabel('Percentile Ranking Against Control Set')
plt.title('Paper Ligands Percentil Ranking: Total Interactions')

plt.ylim(0,100)

# Set y-axis to display in scientific notation with individual tick values
plt.gca().yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
plt.gca().yaxis.get_major_formatter().set_scientific(False)
plt.gca().yaxis.get_major_formatter().set_powerlimits((0,0))

# Rotate x-axis labels by 45 degrees
plt.xticks(rotation=90)

# Set y-axis to display numbers with commas
plt.gca().yaxis.set_major_formatter(FuncFormatter(lambda x, _: f'{int(x):,}'))

#add note for the text
#plt.text(3, 1, "Conformers: " + str(total_ligands), fontsize=12, color='black')
#plt.annotate("Total Atoms = " + str(total_atoms), xy=(0.29, -0.18), xycoords='axes fraction', fontsize=9, color='black')

plt.show()

# %%
# Create a bar plot for real motif count
plt.bar(df['ligand'], df['interaction_percentile'])
plt.xlabel('Paper Ligand')
plt.ylabel('Percentile Ranking Against Control Set')
plt.title('Paper Ligands Percentil Ranking: Total Interactions')

plt.ylim(0,100)

# Set y-axis to display in scientific notation with individual tick values
plt.gca().yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
plt.gca().yaxis.get_major_formatter().set_scientific(False)
plt.gca().yaxis.get_major_formatter().set_powerlimits((0,0))

# Rotate x-axis labels by 45 degrees
plt.xticks(rotation=90)

# Set y-axis to display numbers with commas
plt.gca().yaxis.set_major_formatter(FuncFormatter(lambda x, _: f'{int(x):,}'))

#add note for the text
#plt.text(3, 1, "Conformers: " + str(total_ligands), fontsize=12, color='black')
#plt.annotate("Total Atoms = " + str(total_atoms), xy=(0.29, -0.18), xycoords='axes fraction', fontsize=9, color='black')

plt.show()

# %%
# Create a bar plot for real motif ratio
plt.bar(df['ligand'], df['interaction_percentile'])
plt.xlabel('Paper Ligand')
plt.ylabel('Percentile Ranking Against Control Set')
plt.title('Paper Ligands Percentil Ranking: Total Interactions')

plt.ylim(0,100)

# Set y-axis to display in scientific notation with individual tick values
plt.gca().yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
plt.gca().yaxis.get_major_formatter().set_scientific(False)
plt.gca().yaxis.get_major_formatter().set_powerlimits((0,0))

# Rotate x-axis labels by 45 degrees
plt.xticks(rotation=90)

# Set y-axis to display numbers with commas
plt.gca().yaxis.set_major_formatter(FuncFormatter(lambda x, _: f'{int(x):,}'))

#add note for the text
#plt.text(3, 1, "Conformers: " + str(total_ligands), fontsize=12, color='black')
#plt.annotate("Total Atoms = " + str(total_atoms), xy=(0.29, -0.18), xycoords='axes fraction', fontsize=9, color='black')

plt.show()
