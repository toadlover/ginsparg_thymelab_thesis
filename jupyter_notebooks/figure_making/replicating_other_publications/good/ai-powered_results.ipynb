# %%
#initial import of relevant packages for graphing
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import ScalarFormatter
from matplotlib.ticker import FuncFormatter
#https://stackoverflow.com/questions/32085531/importing-a-csv-file-into-python-to-make-scatterplots-and-histograms

# %%
#read in the data csv
df = pd.read_csv("../../../benchmarking_other_papers/papers/AI-powered_Virtual_Screening_of_Large_Compound_Libraries_leads_to_the_Discovery_of_Novel_Inhibitors_of_Sirtuin-1/analysis_results/paper_ligands_rank.csv")
df
# Out:
#        ligand   best_ddg  ddg_rank  ddg_percentile  best_interaction  \
# 0   Z31269192 -21.191626        93        0.010005              12.0
# 1   Z26395449 -21.088617       103        0.011081              11.0
# 2  Z240678214 -20.520980       172        0.018505              10.0
# 3   Z26395518 -20.322272       196        0.021087              10.0
# 4  Z254577874 -18.940423       629        0.067671              11.0
# 5   Z32440384 -18.854422       669        0.071974              10.0
# 6   Z26395441 -18.430098       871        0.093706              10.0
# 7   Z26395442 -18.043923      1093        0.117590              10.0
# 8   Z26395438 -17.678058      1322        0.142227              10.0
#
#    interaction_rank  interaction_percentile  best_real_motif_count  \
# 0                 9                0.000968                    5.0
# 1               159                0.017106                    7.0
# 2              1286                0.138354                    6.0
# 3              1286                0.138354                    7.0
# 4               159                0.017106                    6.0
# 5              1286                0.138354                    7.0
# 6              1286                0.138354                    6.0
# 7              1286                0.138354                    6.0
# 8              1286                0.138354                    6.0
#
#    real_motif_count_rank  real_motif_count_percentile  best_real_motif_ratio  \
# 0                    141                     0.015169               0.800000
# 1                      1                     0.000108               0.800000
# 2                     25                     0.002690               0.833333
# 3                      1                     0.000108               0.800000
# 4                     25                     0.002690               1.000000
# 5                      1                     0.000108               0.833333
# 6                     25                     0.002690               0.833333
# 7                     25                     0.002690               1.000000
# 8                     25                     0.002690               1.000000
#
#    real_motif_ratio_rank  real_motif_ratio_percentile  Unnamed: 13
# 0                    156                     0.016783          NaN
# 1                    156                     0.016783          NaN
# 2                     97                     0.010436          NaN
# 3                    156                     0.016783          NaN
# 4                      1                     0.000108          NaN
# 5                     97                     0.010436          NaN
# 6                     97                     0.010436          NaN
# 7                      1                     0.000108          NaN
# 8                      1                     0.000108          NaN

# %%
#convert percentiles into percents
df['ddg_percentile'] = (df['ddg_percentile']) * 100
df['interaction_percentile'] = (df['interaction_percentile']) * 100
df['real_motif_count_percentile'] = (df['real_motif_count_percentile']) * 100
df['real_motif_ratio_percentile'] = (df['real_motif_ratio_percentile']) * 100

# %%
# Create a bar plot for ddg
plt.bar(df['ligand'], df['ddg_percentile'])
#plt.xlabel('Paper Ligand')
plt.ylabel('Percentile Ranking Against Control Set')
plt.title('Paper Ligands Percentile Ranking: ddG')

plt.ylim(0,100)

# Set y-axis to display in scientific notation with individual tick values
plt.gca().yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
plt.gca().yaxis.get_major_formatter().set_scientific(False)
plt.gca().yaxis.get_major_formatter().set_powerlimits((0,0))

# Rotate x-axis labels by 45 degrees
plt.xticks(rotation=90)

# Set y-axis to display numbers with commas
plt.gca().yaxis.set_major_formatter(FuncFormatter(lambda x, _: f'{int(x):,}'))

#add note for the text
#plt.text(3, 1, "Conformers: " + str(total_ligands), fontsize=12, color='black')
#plt.annotate("Total Atoms = " + str(total_atoms), xy=(0.29, -0.18), xycoords='axes fraction', fontsize=9, color='black')

plt.show()

# %%
# Create a bar plot for interaction count
plt.bar(df['ligand'], df['interaction_percentile'])
#plt.xlabel('Paper Ligand')
plt.ylabel('Percentile Ranking Against Control Set')
plt.title('Paper Ligands Percentile Ranking: Total Interactions')

plt.ylim(0,100)

# Set y-axis to display in scientific notation with individual tick values
plt.gca().yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
plt.gca().yaxis.get_major_formatter().set_scientific(False)
plt.gca().yaxis.get_major_formatter().set_powerlimits((0,0))

# Rotate x-axis labels by 45 degrees
plt.xticks(rotation=90)

# Set y-axis to display numbers with commas
plt.gca().yaxis.set_major_formatter(FuncFormatter(lambda x, _: f'{int(x):,}'))

#add note for the text
#plt.text(3, 1, "Conformers: " + str(total_ligands), fontsize=12, color='black')
#plt.annotate("Total Atoms = " + str(total_atoms), xy=(0.29, -0.18), xycoords='axes fraction', fontsize=9, color='black')

plt.show()

# %%
# Create a bar plot for real motif count
plt.bar(df['ligand'], df['real_motif_count_percentile'])
#plt.xlabel('Paper Ligand')
plt.ylabel('Percentile Ranking Against Control Set')
plt.title('Paper Ligands Percentile Ranking: Real Motif Count')

plt.ylim(0,100)

# Set y-axis to display in scientific notation with individual tick values
plt.gca().yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
plt.gca().yaxis.get_major_formatter().set_scientific(False)
plt.gca().yaxis.get_major_formatter().set_powerlimits((0,0))

# Rotate x-axis labels by 45 degrees
plt.xticks(rotation=90)

# Set y-axis to display numbers with commas
plt.gca().yaxis.set_major_formatter(FuncFormatter(lambda x, _: f'{int(x):,}'))

#add note for the text
#plt.text(3, 1, "Conformers: " + str(total_ligands), fontsize=12, color='black')
#plt.annotate("Total Atoms = " + str(total_atoms), xy=(0.29, -0.18), xycoords='axes fraction', fontsize=9, color='black')

plt.show()

# %%
# Create a bar plot for real motif ratio
plt.bar(df['ligand'], df['real_motif_ratio_percentile'])
#plt.xlabel('Paper Ligand')
plt.ylabel('Percentile Ranking Against Control Set')
plt.title('Paper Ligands Percentile Ranking: Real Motif Ratio')

plt.ylim(0,100)

# Set y-axis to display in scientific notation with individual tick values
plt.gca().yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
plt.gca().yaxis.get_major_formatter().set_scientific(False)
plt.gca().yaxis.get_major_formatter().set_powerlimits((0,0))

# Rotate x-axis labels by 45 degrees
plt.xticks(rotation=90)

# Set y-axis to display numbers with commas
plt.gca().yaxis.set_major_formatter(FuncFormatter(lambda x, _: f'{int(x):,}'))

#add note for the text
#plt.text(3, 1, "Conformers: " + str(total_ligands), fontsize=12, color='black')
#plt.annotate("Total Atoms = " + str(total_atoms), xy=(0.29, -0.18), xycoords='axes fraction', fontsize=9, color='black')

plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

# load file (no header)
df = pd.read_csv("../../../../benchmarking_other_papers/papers/AI-powered_Virtual_Screening_of_Large_Compound_Libraries_leads_to_the_Discovery_of_Novel_Inhibitors_of_Sirtuin-1/analysis_results/best_ddg.csv", header=None)

# if there is an extra empty trailing column, drop it
df = df.dropna(axis=1, how="all")

# column 0 is the true class: 1 = published ligand, 0 = background
y_true = df[0].astype(int).to_numpy()

# since file is already sorted best -> worst, create a score from row order
n = len(df)
y_score = np.arange(n, 0, -1)

# ROC + AUC
fpr, tpr, thresholds = roc_curve(y_true, y_score)
roc_auc = auc(fpr, tpr)

print(f"Total compounds: {n}")
print(f"Published ligands: {y_true.sum()}")
print(f"Background ligands: {(y_true == 0).sum()}")
print(f"AUC: {roc_auc:.4f}")

# plot
plt.figure(figsize=(6,5))
plt.step(fpr, tpr, where="post")
plt.plot([0, 1], [0, 1], linestyle="--")

plt.xlabel("False Positive Rate", fontsize=14)
plt.ylabel("True Positive Rate", fontsize=14)
#plt.title("ROC Curve")

plt.tick_params(axis='both', labelsize=14)

# AUC box in bottom-right
plt.text(
    0.96, 0.04,
    f"AUC = {roc_auc:.4f}",
    transform=plt.gca().transAxes,
    ha="right",
    va="bottom",
    fontsize=20,
    bbox=dict(boxstyle="round", facecolor="white", edgecolor="black")
)

plt.tight_layout()
plt.show()
# Out:
# Total compounds: 9295
# Published ligands: 9
# Background ligands: 9286
# AUC: 0.9389

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

# load file (no header)
df = pd.read_csv("../../../../benchmarking_other_papers/papers/AI-powered_Virtual_Screening_of_Large_Compound_Libraries_leads_to_the_Discovery_of_Novel_Inhibitors_of_Sirtuin-1/analysis_results/best_interactions.csv", header=None)

# if there is an extra empty trailing column, drop it
df = df.dropna(axis=1, how="all")

# column 0 is the true class: 1 = published ligand, 0 = background
y_true = df[0].astype(int).to_numpy()

# since file is already sorted best -> worst, create a score from row order
n = len(df)
y_score = np.arange(n, 0, -1)

# ROC + AUC
fpr, tpr, thresholds = roc_curve(y_true, y_score)
roc_auc = auc(fpr, tpr)

print(f"Total compounds: {n}")
print(f"Published ligands: {y_true.sum()}")
print(f"Background ligands: {(y_true == 0).sum()}")
print(f"AUC: {roc_auc:.4f}")

# plot
plt.figure(figsize=(6,5))
plt.step(fpr, tpr, where="post")
plt.plot([0, 1], [0, 1], linestyle="--")

plt.xlabel("False Positive Rate", fontsize=14)
plt.ylabel("True Positive Rate", fontsize=14)
#plt.title("ROC Curve")

plt.tick_params(axis='both', labelsize=14)

# AUC box in bottom-right
plt.text(
    0.96, 0.04,
    f"AUC = {roc_auc:.4f}",
    transform=plt.gca().transAxes,
    ha="right",
    va="bottom",
    fontsize=20,
    bbox=dict(boxstyle="round", facecolor="white", edgecolor="black")
)

plt.tight_layout()
plt.show()
# Out:
# Total compounds: 9295
# Published ligands: 9
# Background ligands: 9286
# AUC: 0.6623

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

# load file (no header)
df = pd.read_csv("../../../../benchmarking_other_papers/papers/AI-powered_Virtual_Screening_of_Large_Compound_Libraries_leads_to_the_Discovery_of_Novel_Inhibitors_of_Sirtuin-1/analysis_results/best_real_count.csv", header=None)

# if there is an extra empty trailing column, drop it
df = df.dropna(axis=1, how="all")

# column 0 is the true class: 1 = published ligand, 0 = background
y_true = df[0].astype(int).to_numpy()

# since file is already sorted best -> worst, create a score from row order
n = len(df)
y_score = np.arange(n, 0, -1)

# ROC + AUC
fpr, tpr, thresholds = roc_curve(y_true, y_score)
roc_auc = auc(fpr, tpr)

print(f"Total compounds: {n}")
print(f"Published ligands: {y_true.sum()}")
print(f"Background ligands: {(y_true == 0).sum()}")
print(f"AUC: {roc_auc:.4f}")

# plot
plt.figure(figsize=(6,5))
plt.step(fpr, tpr, where="post")
plt.plot([0, 1], [0, 1], linestyle="--")

plt.xlabel("False Positive Rate", fontsize=14)
plt.ylabel("True Positive Rate", fontsize=14)
#plt.title("ROC Curve")

plt.tick_params(axis='both', labelsize=14)

# AUC box in bottom-right
plt.text(
    0.96, 0.04,
    f"AUC = {roc_auc:.4f}",
    transform=plt.gca().transAxes,
    ha="right",
    va="bottom",
    fontsize=20,
    bbox=dict(boxstyle="round", facecolor="white", edgecolor="black")
)

plt.tight_layout()
plt.show()
# Out:
# Total compounds: 9295
# Published ligands: 9
# Background ligands: 9286
# AUC: 0.9840

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

# load file (no header)
df = pd.read_csv("../../../../benchmarking_other_papers/papers/AI-powered_Virtual_Screening_of_Large_Compound_Libraries_leads_to_the_Discovery_of_Novel_Inhibitors_of_Sirtuin-1/analysis_results/best_real_ratio.csv", header=None)

# if there is an extra empty trailing column, drop it
df = df.dropna(axis=1, how="all")

# column 0 is the true class: 1 = published ligand, 0 = background
y_true = df[0].astype(int).to_numpy()

# since file is already sorted best -> worst, create a score from row order
n = len(df)
y_score = np.arange(n, 0, -1)

# ROC + AUC
fpr, tpr, thresholds = roc_curve(y_true, y_score)
roc_auc = auc(fpr, tpr)

print(f"Total compounds: {n}")
print(f"Published ligands: {y_true.sum()}")
print(f"Background ligands: {(y_true == 0).sum()}")
print(f"AUC: {roc_auc:.4f}")

# plot
plt.figure(figsize=(6,5))
plt.step(fpr, tpr, where="post")
plt.plot([0, 1], [0, 1], linestyle="--")

plt.xlabel("False Positive Rate", fontsize=14)
plt.ylabel("True Positive Rate", fontsize=14)
#plt.title("ROC Curve")

plt.tick_params(axis='both', labelsize=14)

# AUC box in bottom-right
plt.text(
    0.96, 0.04,
    f"AUC = {roc_auc:.4f}",
    transform=plt.gca().transAxes,
    ha="right",
    va="bottom",
    fontsize=20,
    bbox=dict(boxstyle="round", facecolor="white", edgecolor="black")
)

plt.tight_layout()
plt.show()
# Out:
# Total compounds: 9295
# Published ligands: 9
# Background ligands: 9286
# AUC: 0.9805
