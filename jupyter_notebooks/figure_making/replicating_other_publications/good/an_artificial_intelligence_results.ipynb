# %%
#initial import of relevant packages for graphing
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import ScalarFormatter
from matplotlib.ticker import FuncFormatter
#https://stackoverflow.com/questions/32085531/importing-a-csv-file-into-python-to-make-scatterplots-and-histograms

# %%
#read in the data csv
df = pd.read_csv("../../../benchmarking_other_papers/papers/An_artificial_intelligence_accelerated_virtual_screening_platform_for_drug_discovery/analysis_space/paper_ligands_rank.csv")
df
# Out:
#         ligand   best_ddg  ddg_rank  ddg_percentile  best_interaction  \
# 0  Z8739902234 -20.198272        16        0.001802              11.0
# 1  Z8739902231 -19.979135        22        0.002478              11.0
# 2  Z4315497494 -19.617113        30        0.003380              10.0
# 3  Z8718594710 -19.408419        33        0.003717               8.0
# 4  Z8718594701 -17.092035       294        0.033119               9.0
# 5  Z8718594704 -16.370642       529        0.059592              10.0
# 6  Z3831472882 -15.691986       870        0.098006               9.0
# 7  Z4415557415 -15.417397      1047        0.117945              10.0
# 8  Z8739905023 -13.804121      2651        0.298637               8.0
#
#    interaction_rank  interaction_percentile  best_real_motif_count  \
# 0                91                0.010251                    4.0
# 1                91                0.010251                    3.0
# 2               639                0.071984                    5.0
# 3              4688                0.528106                    2.0
# 4              2275                0.256280                    3.0
# 5               639                0.071984                    3.0
# 6              2275                0.256280                    4.0
# 7               639                0.071984                    3.0
# 8              4688                0.528106                    3.0
#
#    real_motif_count_rank  real_motif_count_percentile  best_real_motif_ratio  \
# 0                     98                     0.011040               0.666667
# 1                    614                     0.069168               0.500000
# 2                     14                     0.001577               0.625000
# 3                   2394                     0.269686               0.666667
# 4                    614                     0.069168               0.500000
# 5                    614                     0.069168               0.600000
# 6                     98                     0.011040               0.500000
# 7                    614                     0.069168               0.750000
# 8                    614                     0.069168               0.600000
#
#    real_motif_ratio_rank  real_motif_ratio_percentile  Unnamed: 13
# 0                    448                     0.050468          NaN
# 1                   1305                     0.147009          NaN
# 2                    822                     0.092599          NaN
# 3                    448                     0.050468          NaN
# 4                   1305                     0.147009          NaN
# 5                    835                     0.094063          NaN
# 6                   1305                     0.147009          NaN
# 7                    153                     0.017236          NaN
# 8                    835                     0.094063          NaN

# %%
#convert percentiles into percents
#df['ddg_percentile'] = (1 - df['ddg_percentile']) * 100
#df['interaction_percentile'] = (1 - df['interaction_percentile']) * 100
#df['real_motif_count_percentile'] = (1 - df['real_motif_count_percentile']) * 100
#df['real_motif_ratio_percentile'] = (1 - df['real_motif_ratio_percentile']) * 100

# %%
#convert percentiles into percents
df['ddg_percentile'] = (df['ddg_percentile']) * 100
df['interaction_percentile'] = (df['interaction_percentile']) * 100
df['real_motif_count_percentile'] = (df['real_motif_count_percentile']) * 100
df['real_motif_ratio_percentile'] = (df['real_motif_ratio_percentile']) * 100

# %%
# Create a bar plot for ddg
plt.bar(df['ligand'], df['ddg_percentile'])
#plt.xlabel('Paper Ligand')
plt.ylabel('Percentile Ranking Against Control Set')
plt.title('Paper Ligands Percentile Ranking: ddG')

plt.ylim(0,100)

# Set y-axis to display in scientific notation with individual tick values
plt.gca().yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
plt.gca().yaxis.get_major_formatter().set_scientific(False)
plt.gca().yaxis.get_major_formatter().set_powerlimits((0,0))

# Rotate x-axis labels by 45 degrees
plt.xticks(rotation=90)

# Set y-axis to display numbers with commas
plt.gca().yaxis.set_major_formatter(FuncFormatter(lambda x, _: f'{int(x):,}'))

#add note for the text
#plt.text(3, 1, "Conformers: " + str(total_ligands), fontsize=12, color='black')
#plt.annotate("Total Atoms = " + str(total_atoms), xy=(0.29, -0.18), xycoords='axes fraction', fontsize=9, color='black')

plt.show()

# %%
# Create a bar plot for interaction count
plt.bar(df['ligand'], df['interaction_percentile'])
#plt.xlabel('Paper Ligand')
plt.ylabel('Percentile Ranking Against Control Set')
plt.title('Paper Ligands Percentile Ranking: Total Interactions')

plt.ylim(0,100)

# Set y-axis to display in scientific notation with individual tick values
plt.gca().yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
plt.gca().yaxis.get_major_formatter().set_scientific(False)
plt.gca().yaxis.get_major_formatter().set_powerlimits((0,0))

# Rotate x-axis labels by 45 degrees
plt.xticks(rotation=90)

# Set y-axis to display numbers with commas
plt.gca().yaxis.set_major_formatter(FuncFormatter(lambda x, _: f'{int(x):,}'))

#add note for the text
#plt.text(3, 1, "Conformers: " + str(total_ligands), fontsize=12, color='black')
#plt.annotate("Total Atoms = " + str(total_atoms), xy=(0.29, -0.18), xycoords='axes fraction', fontsize=9, color='black')

plt.show()

# %%
# Create a bar plot for real motif count
plt.bar(df['ligand'], df['real_motif_count_percentile'])
#plt.xlabel('Paper Ligand')
plt.ylabel('Percentile Ranking Against Control Set')
plt.title('Paper Ligands Percentile Ranking: Real Motif Count')

plt.ylim(0,100)

# Set y-axis to display in scientific notation with individual tick values
plt.gca().yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
plt.gca().yaxis.get_major_formatter().set_scientific(False)
plt.gca().yaxis.get_major_formatter().set_powerlimits((0,0))

# Rotate x-axis labels by 45 degrees
plt.xticks(rotation=90)

# Set y-axis to display numbers with commas
plt.gca().yaxis.set_major_formatter(FuncFormatter(lambda x, _: f'{int(x):,}'))

#add note for the text
#plt.text(3, 1, "Conformers: " + str(total_ligands), fontsize=12, color='black')
#plt.annotate("Total Atoms = " + str(total_atoms), xy=(0.29, -0.18), xycoords='axes fraction', fontsize=9, color='black')

plt.show()

# %%
# Create a bar plot for real motif ratio
plt.bar(df['ligand'], df['real_motif_ratio_percentile'])
#plt.xlabel('Paper Ligand')
plt.ylabel('Percentile Ranking Against Control Set')
plt.title('Paper Ligands Percentile Ranking: Real Motif Ratio')

plt.ylim(0,100)

# Set y-axis to display in scientific notation with individual tick values
plt.gca().yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
plt.gca().yaxis.get_major_formatter().set_scientific(False)
plt.gca().yaxis.get_major_formatter().set_powerlimits((0,0))

# Rotate x-axis labels by 45 degrees
plt.xticks(rotation=90)

# Set y-axis to display numbers with commas
plt.gca().yaxis.set_major_formatter(FuncFormatter(lambda x, _: f'{int(x):,}'))

#add note for the text
#plt.text(3, 1, "Conformers: " + str(total_ligands), fontsize=12, color='black')
#plt.annotate("Total Atoms = " + str(total_atoms), xy=(0.29, -0.18), xycoords='axes fraction', fontsize=9, color='black')

plt.show()

# %%
dirname = "An_artificial_intelligence_accelerated_virtual_screening_platform_for_drug_discovery"
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

# load file (no header)
df = pd.read_csv("../../../../benchmarking_other_papers/papers/" + dirname + "/analysis_space/best_ddg.csv", header=None)

# if there is an extra empty trailing column, drop it
df = df.dropna(axis=1, how="all")

# column 0 is the true class: 1 = published ligand, 0 = background
y_true = df[0].astype(int).to_numpy()

# since file is already sorted best -> worst, create a score from row order
n = len(df)
y_score = np.arange(n, 0, -1)

# ROC + AUC
fpr, tpr, thresholds = roc_curve(y_true, y_score)
roc_auc = auc(fpr, tpr)

print(f"Total compounds: {n}")
print(f"Published ligands: {y_true.sum()}")
print(f"Background ligands: {(y_true == 0).sum()}")
print(f"AUC: {roc_auc:.4f}")

# plot
plt.figure(figsize=(6,5))
plt.step(fpr, tpr, where="post")
plt.plot([0, 1], [0, 1], linestyle="--")

plt.xlabel("False Positive Rate", fontsize=14)
plt.ylabel("True Positive Rate", fontsize=14)
#plt.title("ROC Curve")

plt.tick_params(axis='both', labelsize=14)

# AUC box in bottom-right
plt.text(
    0.96, 0.04,
    f"AUC = {roc_auc:.4f}",
    transform=plt.gca().transAxes,
    ha="right",
    va="bottom",
    fontsize=20,
    bbox=dict(boxstyle="round", facecolor="white", edgecolor="black")
)

plt.tight_layout()
plt.show()
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

# load file (no header)
df = pd.read_csv("../../../../benchmarking_other_papers/papers/" + dirname + "/analysis_space/best_interactions.csv", header=None)

# if there is an extra empty trailing column, drop it
df = df.dropna(axis=1, how="all")

# column 0 is the true class: 1 = published ligand, 0 = background
y_true = df[0].astype(int).to_numpy()

# since file is already sorted best -> worst, create a score from row order
n = len(df)
y_score = np.arange(n, 0, -1)

# ROC + AUC
fpr, tpr, thresholds = roc_curve(y_true, y_score)
roc_auc = auc(fpr, tpr)

print(f"Total compounds: {n}")
print(f"Published ligands: {y_true.sum()}")
print(f"Background ligands: {(y_true == 0).sum()}")
print(f"AUC: {roc_auc:.4f}")

# plot
plt.figure(figsize=(6,5))
plt.step(fpr, tpr, where="post")
plt.plot([0, 1], [0, 1], linestyle="--")

plt.xlabel("False Positive Rate", fontsize=14)
plt.ylabel("True Positive Rate", fontsize=14)
#plt.title("ROC Curve")

plt.tick_params(axis='both', labelsize=14)

# AUC box in bottom-right
plt.text(
    0.96, 0.04,
    f"AUC = {roc_auc:.4f}",
    transform=plt.gca().transAxes,
    ha="right",
    va="bottom",
    fontsize=20,
    bbox=dict(boxstyle="round", facecolor="white", edgecolor="black")
)

plt.tight_layout()
plt.show()
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

# load file (no header)
df = pd.read_csv("../../../../benchmarking_other_papers/papers/" + dirname + "/analysis_space/best_real_count.csv", header=None)

# if there is an extra empty trailing column, drop it
df = df.dropna(axis=1, how="all")

# column 0 is the true class: 1 = published ligand, 0 = background
y_true = df[0].astype(int).to_numpy()

# since file is already sorted best -> worst, create a score from row order
n = len(df)
y_score = np.arange(n, 0, -1)

# ROC + AUC
fpr, tpr, thresholds = roc_curve(y_true, y_score)
roc_auc = auc(fpr, tpr)

print(f"Total compounds: {n}")
print(f"Published ligands: {y_true.sum()}")
print(f"Background ligands: {(y_true == 0).sum()}")
print(f"AUC: {roc_auc:.4f}")

# plot
plt.figure(figsize=(6,5))
plt.step(fpr, tpr, where="post")
plt.plot([0, 1], [0, 1], linestyle="--")

plt.xlabel("False Positive Rate", fontsize=14)
plt.ylabel("True Positive Rate", fontsize=14)
#plt.title("ROC Curve")

plt.tick_params(axis='both', labelsize=14)

# AUC box in bottom-right
plt.text(
    0.96, 0.04,
    f"AUC = {roc_auc:.4f}",
    transform=plt.gca().transAxes,
    ha="right",
    va="bottom",
    fontsize=20,
    bbox=dict(boxstyle="round", facecolor="white", edgecolor="black")
)

plt.tight_layout()
plt.show()
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

# load file (no header)
df = pd.read_csv("../../../../benchmarking_other_papers/papers/" + dirname + "/analysis_space/best_real_ratio.csv", header=None)

# if there is an extra empty trailing column, drop it
df = df.dropna(axis=1, how="all")

# column 0 is the true class: 1 = published ligand, 0 = background
y_true = df[0].astype(int).to_numpy()

# since file is already sorted best -> worst, create a score from row order
n = len(df)
y_score = np.arange(n, 0, -1)

# ROC + AUC
fpr, tpr, thresholds = roc_curve(y_true, y_score)
roc_auc = auc(fpr, tpr)

print(f"Total compounds: {n}")
print(f"Published ligands: {y_true.sum()}")
print(f"Background ligands: {(y_true == 0).sum()}")
print(f"AUC: {roc_auc:.4f}")

# plot
plt.figure(figsize=(6,5))
plt.step(fpr, tpr, where="post")
plt.plot([0, 1], [0, 1], linestyle="--")

plt.xlabel("False Positive Rate", fontsize=14)
plt.ylabel("True Positive Rate", fontsize=14)
#plt.title("ROC Curve")

plt.tick_params(axis='both', labelsize=14)

# AUC box in bottom-right
plt.text(
    0.96, 0.04,
    f"AUC = {roc_auc:.4f}",
    transform=plt.gca().transAxes,
    ha="right",
    va="bottom",
    fontsize=20,
    bbox=dict(boxstyle="round", facecolor="white", edgecolor="black")
)

plt.tight_layout()
plt.show()
# Out:
# Total compounds: 8877
# Published ligands: 9
# Background ligands: 8868
# AUC: 0.9318
# Total compounds: 8877
# Published ligands: 9
# Background ligands: 8868
# AUC: 0.6167
# Total compounds: 8877
# Published ligands: 9
# Background ligands: 8868
# AUC: 0.7613
# Total compounds: 8877
# Published ligands: 9
# Background ligands: 8868
# AUC: 0.8324
