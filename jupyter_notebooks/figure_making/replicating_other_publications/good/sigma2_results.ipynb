# %%
#initial import of relevant packages for graphing
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import ScalarFormatter
from matplotlib.ticker import FuncFormatter
#https://stackoverflow.com/questions/32085531/importing-a-csv-file-into-python-to-make-scatterplots-and-histograms

# %%
#read in the data csv
df = pd.read_csv("../../../../benchmarking_other_papers/papers/Structures_of_the_sigma2_receptor_enable_docking_for_bioactive_ligand_discovery/analysis_space/paper_ligands_rank.csv")
df
# Out:
#               ligand   best_ddg  ddg_rank  ddg_percentile  best_interaction  \
# 0        Z4510627652 -22.415302         1        0.000100              14.0
# 1        Z4510628191 -22.376932         2        0.000201              12.0
# 2        Z4857158944 -21.627406         8        0.000803              16.0
# 3   ZINC000895657866 -20.718167        30        0.003012              15.0
# 4        Z4493929234 -19.846248        80        0.008032              15.0
# 5   ZINC000450573233 -19.810030        84        0.008434              14.0
# 6   ZINC000533478938 -19.364113       126        0.012651              16.0
# 7        Z1241145220 -18.501317       297        0.029819              14.0
# 8   ZINC000544117725 -17.797383       569        0.057129              12.0
# 9   ZINC000921927365 -17.679589       624        0.062651              14.0
# 10       Z4634276811 -17.242367       899        0.090261              13.0
# 11       Z1665845742 -17.142955       957        0.096084              14.0
# 12       Z4430417979 -16.793180      1227        0.123193              13.0
# 13       Z1665798906 -16.736784      1284        0.128916              13.0
# 14       Z4430418526 -16.293712      1710        0.171687              12.0
# 15  ZINC000656714762 -16.090984      1962        0.196988              13.0
# 16       Z4510628128 -16.070201      1979        0.198695              13.0
# 17  ZINC000548355486 -16.040226      2009        0.201707              14.0
# 18  ZINC001170548029 -15.824515      2268        0.227711              14.0
# 19  ZINC000348332392 -15.571451      2606        0.261647              13.0
# 20  ZINC001196519317 -15.401071      2874        0.288554              12.0
# 21  ZINC001460312963 -14.972479      3547        0.356124              13.0
# 22  ZINC001237901728 -14.526073      4362        0.437952              13.0
# 23  ZINC001254761628 -13.652978      5940        0.596386              11.0
# 24  ZINC000170908795 -12.273125      8301        0.833434              11.0
#
#     interaction_rank  interaction_percentile  best_real_motif_count  \
# 0                748                0.075100                    6.0
# 1               4523                0.454116                    4.0
# 2                  4                0.000402                    7.0
# 3                108                0.010843                    6.0
# 4                108                0.010843                    7.0
# 5                748                0.075100                    7.0
# 6                  4                0.000402                    5.0
# 7                748                0.075100                    8.0
# 8               4523                0.454116                    5.0
# 9                748                0.075100                    6.0
# 10              2361                0.237048                    5.0
# 11               748                0.075100                    6.0
# 12              2361                0.237048                    6.0
# 13              2361                0.237048                    6.0
# 14              4523                0.454116                    4.0
# 15              2361                0.237048                    4.0
# 16              2361                0.237048                    5.0
# 17               748                0.075100                    5.0
# 18               748                0.075100                    5.0
# 19              2361                0.237048                    6.0
# 20              4523                0.454116                    5.0
# 21              2361                0.237048                    5.0
# 22              2361                0.237048                    4.0
# 23              6543                0.656928                    6.0
# 24              6543                0.656928                    4.0
#
#     real_motif_count_rank  real_motif_count_percentile  best_real_motif_ratio  \
# 0                      55                     0.005522               1.000000
# 1                    1157                     0.116165               0.750000
# 2                       9                     0.000904               1.000000
# 3                      55                     0.005522               1.000000
# 4                       9                     0.000904               1.000000
# 5                       9                     0.000904               1.000000
# 6                     299                     0.030020               0.750000
# 7                       1                     0.000100               1.000000
# 8                     299                     0.030020               1.000000
# 9                      55                     0.005522               1.000000
# 10                    299                     0.030020               0.666667
# 11                     55                     0.005522               1.000000
# 12                     55                     0.005522               1.000000
# 13                     55                     0.005522               1.000000
# 14                   1157                     0.116165               1.000000
# 15                   1157                     0.116165               1.000000
# 16                    299                     0.030020               1.000000
# 17                    299                     0.030020               0.750000
# 18                    299                     0.030020               0.800000
# 19                     55                     0.005522               1.000000
# 20                    299                     0.030020               1.000000
# 21                    299                     0.030020               0.666667
# 22                   1157                     0.116165               0.600000
# 23                     55                     0.005522               0.800000
# 24                   1157                     0.116165               0.666667
#
#     real_motif_ratio_rank  real_motif_ratio_percentile  Unnamed: 13
# 0                       1                     0.000100          NaN
# 1                    1323                     0.132831          NaN
# 2                       1                     0.000100          NaN
# 3                       1                     0.000100          NaN
# 4                       1                     0.000100          NaN
# 5                       1                     0.000100          NaN
# 6                    1323                     0.132831          NaN
# 7                       1                     0.000100          NaN
# 8                       1                     0.000100          NaN
# 9                       1                     0.000100          NaN
# 10                   2144                     0.215261          NaN
# 11                      1                     0.000100          NaN
# 12                      1                     0.000100          NaN
# 13                      1                     0.000100          NaN
# 14                      1                     0.000100          NaN
# 15                      1                     0.000100          NaN
# 16                      1                     0.000100          NaN
# 17                   1323                     0.132831          NaN
# 18                    881                     0.088454          NaN
# 19                      1                     0.000100          NaN
# 20                      1                     0.000100          NaN
# 21                   2144                     0.215261          NaN
# 22                   3083                     0.309538          NaN
# 23                    881                     0.088454          NaN
# 24                   2144                     0.215261          NaN

# %%
#convert percentiles into percents
#df['ddg_percentile'] = (1 - df['ddg_percentile']) * 100
#df['interaction_percentile'] = (1 - df['interaction_percentile']) * 100
#df['real_motif_count_percentile'] = (1 - df['real_motif_count_percentile']) * 100
#df['real_motif_ratio_percentile'] = (1 - df['real_motif_ratio_percentile']) * 100

# %%
#convert percentiles into percents
df['ddg_percentile'] = (df['ddg_percentile']) * 100
df['interaction_percentile'] = (df['interaction_percentile']) * 100
df['real_motif_count_percentile'] = (df['real_motif_count_percentile']) * 100
df['real_motif_ratio_percentile'] = (df['real_motif_ratio_percentile']) * 100

# %%
# Create a bar plot for ddg
plt.bar(df['ligand'], df['ddg_percentile'])
#plt.xlabel('Paper Ligand')
plt.ylabel('Percentile Ranking Against Control Set')
plt.title('Paper Ligands Percentile Ranking: ddG')

plt.ylim(0,100)

# Set y-axis to display in scientific notation with individual tick values
plt.gca().yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
plt.gca().yaxis.get_major_formatter().set_scientific(False)
plt.gca().yaxis.get_major_formatter().set_powerlimits((0,0))

# Rotate x-axis labels by 45 degrees
plt.xticks(rotation=90)

# Set y-axis to display numbers with commas
plt.gca().yaxis.set_major_formatter(FuncFormatter(lambda x, _: f'{int(x):,}'))

#add note for the text
#plt.text(3, 1, "Conformers: " + str(total_ligands), fontsize=12, color='black')
#plt.annotate("Total Atoms = " + str(total_atoms), xy=(0.29, -0.18), xycoords='axes fraction', fontsize=9, color='black')

plt.show()

# %%
# Create a bar plot for interaction count
plt.bar(df['ligand'], df['interaction_percentile'])
#plt.xlabel('Paper Ligand')
plt.ylabel('Percentile Ranking Against Control Set')
plt.title('Paper Ligands Percentile Ranking: Total Interactions')

plt.ylim(0,100)

# Set y-axis to display in scientific notation with individual tick values
plt.gca().yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
plt.gca().yaxis.get_major_formatter().set_scientific(False)
plt.gca().yaxis.get_major_formatter().set_powerlimits((0,0))

# Rotate x-axis labels by 45 degrees
plt.xticks(rotation=90)

# Set y-axis to display numbers with commas
plt.gca().yaxis.set_major_formatter(FuncFormatter(lambda x, _: f'{int(x):,}'))

#add note for the text
#plt.text(3, 1, "Conformers: " + str(total_ligands), fontsize=12, color='black')
#plt.annotate("Total Atoms = " + str(total_atoms), xy=(0.29, -0.18), xycoords='axes fraction', fontsize=9, color='black')

plt.show()

# %%
# Create a bar plot for real motif count
plt.bar(df['ligand'], df['real_motif_count_percentile'])
#plt.xlabel('Paper Ligand')
plt.ylabel('Percentile Ranking Against Control Set')
plt.title('Paper Ligands Percentile Ranking: Real Motif Count')

plt.ylim(0,100)

# Set y-axis to display in scientific notation with individual tick values
plt.gca().yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
plt.gca().yaxis.get_major_formatter().set_scientific(False)
plt.gca().yaxis.get_major_formatter().set_powerlimits((0,0))

# Rotate x-axis labels by 45 degrees
plt.xticks(rotation=90)

# Set y-axis to display numbers with commas
plt.gca().yaxis.set_major_formatter(FuncFormatter(lambda x, _: f'{int(x):,}'))

#add note for the text
#plt.text(3, 1, "Conformers: " + str(total_ligands), fontsize=12, color='black')
#plt.annotate("Total Atoms = " + str(total_atoms), xy=(0.29, -0.18), xycoords='axes fraction', fontsize=9, color='black')

plt.show()

# %%
# Create a bar plot for real motif ratio
plt.bar(df['ligand'], df['real_motif_ratio_percentile'])
#plt.xlabel('Paper Ligand')
plt.ylabel('Percentile Ranking Against Control Set')
plt.title('Paper Ligands Percentile Ranking: Real Motif Ratio')

plt.ylim(0,100)

# Set y-axis to display in scientific notation with individual tick values
plt.gca().yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
plt.gca().yaxis.get_major_formatter().set_scientific(False)
plt.gca().yaxis.get_major_formatter().set_powerlimits((0,0))

# Rotate x-axis labels by 45 degrees
plt.xticks(rotation=90)

# Set y-axis to display numbers with commas
plt.gca().yaxis.set_major_formatter(FuncFormatter(lambda x, _: f'{int(x):,}'))

#add note for the text
#plt.text(3, 1, "Conformers: " + str(total_ligands), fontsize=12, color='black')
#plt.annotate("Total Atoms = " + str(total_atoms), xy=(0.29, -0.18), xycoords='axes fraction', fontsize=9, color='black')

plt.show()
