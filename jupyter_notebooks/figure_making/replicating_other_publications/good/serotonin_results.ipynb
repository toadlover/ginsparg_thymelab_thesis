# %%
#initial import of relevant packages for graphing
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import ScalarFormatter
from matplotlib.ticker import FuncFormatter
#https://stackoverflow.com/questions/32085531/importing-a-csv-file-into-python-to-make-scatterplots-and-histograms

# %%
#read in the data csv
df = pd.read_csv("../../../../benchmarking_other_papers/papers/Structure-based_discovery_of_conformationally_selective_inhibitors_of_the_serotonin_transporter/analysis_space/paper_ligands_rank.csv")
df
# Out:
#               ligand   best_ddg  ddg_rank  ddg_percentile  best_interaction  \
# 0   ZINC000305339642 -25.021983        45        0.004601              12.0
# 1   ZINC000269761690 -23.665339       127        0.012984              12.0
# 2   ZINC000677296032 -22.199704       333        0.034046              12.0
# 3        Z4135312239 -21.585884       486        0.049688              11.0
# 4   ZINC001170690351 -19.636309      1382        0.141294              11.0
# 5        Z4135312264 -19.438844      1493        0.152643              12.0
# 6   ZINC000897222313 -19.349084      1572        0.160720              12.0
# 7   ZINC000443438219 -19.287678      1615        0.165116              11.0
# 8        Z4145515674 -19.192011      1678        0.171557              12.0
# 9   ZINC000863582102 -19.144577      1709        0.174727              11.0
# 10  ZINC000277296162 -19.070126      1762        0.180145              11.0
# 11  ZINC000348114651 -18.303925      2383        0.243636              12.0
# 12  ZINC000443438221 -18.297651      2389        0.244249              12.0
# 13  ZINC000294308141 -18.251530      2434        0.248850              10.0
# 14  ZINC000853098204 -18.207859      2476        0.253144              12.0
# 15  ZINC000580533739 -17.762514      2869        0.293324              12.0
# 16  ZINC000417864931 -17.623020      3015        0.308251              12.0
# 17  ZINC000623756919 -17.622340      3017        0.308455              11.0
# 18  ZINC000657329003 -17.365223      3285        0.335855              13.0
# 19  ZINC000894225026 -17.330513      3334        0.340865              11.0
# 20  ZINC000236204386 -17.240269      3450        0.352725              11.0
# 21       Z4167665784 -17.182531      3503        0.358143              12.0
# 22  ZINC000044494100 -17.120768      3575        0.365505              11.0
# 23  ZINC000623997601 -16.720037      4008        0.409774              13.0
# 24  ZINC000420267969 -16.578765      4167        0.426030              12.0
# 25  ZINC000900380018 -16.244370      4538        0.463961              11.0
# 26  ZINC000634713432 -14.207893      6892        0.704631              10.0
# 27  ZINC000387330406 -10.584030      9460        0.967181               7.0
#
#     interaction_rank  interaction_percentile  best_real_motif_count  \
# 0               1485                0.151825                    7.0
# 1               1485                0.151825                    7.0
# 2               1485                0.151825                    7.0
# 3               4222                0.431653                    3.0
# 4               4222                0.431653                    5.0
# 5               1485                0.151825                    4.0
# 6               1485                0.151825                    5.0
# 7               4222                0.431653                    5.0
# 8               1485                0.151825                    6.0
# 9               4222                0.431653                    4.0
# 10              4222                0.431653                    4.0
# 11              1485                0.151825                    6.0
# 12              1485                0.151825                    4.0
# 13              6451                0.659544                    6.0
# 14              1485                0.151825                    5.0
# 15              1485                0.151825                    5.0
# 16              1485                0.151825                    5.0
# 17              4222                0.431653                    4.0
# 18               172                0.017585                    4.0
# 19              4222                0.431653                    4.0
# 20              4222                0.431653                    4.0
# 21              1485                0.151825                    4.0
# 22              4222                0.431653                    4.0
# 23               172                0.017585                    5.0
# 24              1485                0.151825                    6.0
# 25              4222                0.431653                    4.0
# 26              6451                0.659544                    4.0
# 27              9459                0.967079                    2.0
#
#     real_motif_count_rank  real_motif_count_percentile  best_real_motif_ratio  \
# 0                      10                     0.001022               0.875000
# 1                      10                     0.001022               1.000000
# 2                      10                     0.001022               1.000000
# 3                    2669                     0.272876               0.375000
# 4                     301                     0.030774               0.750000
# 5                     974                     0.099581               0.500000
# 6                     301                     0.030774               0.750000
# 7                     301                     0.030774               0.750000
# 8                      51                     0.005214               0.800000
# 9                     974                     0.099581               0.750000
# 10                    974                     0.099581               0.750000
# 11                     51                     0.005214               1.000000
# 12                    974                     0.099581               0.750000
# 13                     51                     0.005214               1.000000
# 14                    301                     0.030774               0.625000
# 15                    301                     0.030774               0.555556
# 16                    301                     0.030774               0.571429
# 17                    974                     0.099581               0.800000
# 18                    974                     0.099581               0.666667
# 19                    974                     0.099581               0.750000
# 20                    974                     0.099581               1.000000
# 21                    974                     0.099581               0.600000
# 22                    974                     0.099581               1.000000
# 23                    301                     0.030774               0.750000
# 24                     51                     0.005214               0.800000
# 25                    974                     0.099581               0.666667
# 26                    974                     0.099581               0.750000
# 27                   5683                     0.581024               0.500000
#
#     real_motif_ratio_rank  real_motif_ratio_percentile  Unnamed: 13
# 0                     146                     0.014927          NaN
# 1                       1                     0.000102          NaN
# 2                       1                     0.000102          NaN
# 3                    5621                     0.574686          NaN
# 4                     424                     0.043349          NaN
# 5                    2307                     0.235865          NaN
# 6                     424                     0.043349          NaN
# 7                     424                     0.043349          NaN
# 8                     246                     0.025151          NaN
# 9                     424                     0.043349          NaN
# 10                    424                     0.043349          NaN
# 11                      1                     0.000102          NaN
# 12                    424                     0.043349          NaN
# 13                      1                     0.000102          NaN
# 14                   1368                     0.139863          NaN
# 15                   2271                     0.232185          NaN
# 16                   2061                     0.210715          NaN
# 17                    246                     0.025151          NaN
# 18                    858                     0.087721          NaN
# 19                    424                     0.043349          NaN
# 20                      1                     0.000102          NaN
# 21                   1418                     0.144975          NaN
# 22                      1                     0.000102          NaN
# 23                    424                     0.043349          NaN
# 24                    246                     0.025151          NaN
# 25                    858                     0.087721          NaN
# 26                    424                     0.043349          NaN
# 27                   2307                     0.235865          NaN

# %%
#convert percentiles into percents
#df['ddg_percentile'] = (1 - df['ddg_percentile']) * 100
#df['interaction_percentile'] = (1 - df['interaction_percentile']) * 100
#df['real_motif_count_percentile'] = (1 - df['real_motif_count_percentile']) * 100
#df['real_motif_ratio_percentile'] = (1 - df['real_motif_ratio_percentile']) * 100

# %%
#convert percentiles into percents
df['ddg_percentile'] = (df['ddg_percentile']) * 100
df['interaction_percentile'] = (df['interaction_percentile']) * 100
df['real_motif_count_percentile'] = (df['real_motif_count_percentile']) * 100
df['real_motif_ratio_percentile'] = (df['real_motif_ratio_percentile']) * 100

# %%
# Create a bar plot for ddg
plt.bar(df['ligand'], df['ddg_percentile'])
#plt.xlabel('Paper Ligand')
plt.ylabel('Percentile Ranking Against Control Set')
plt.title('Paper Ligands Percentile Ranking: ddG')

plt.ylim(0,100)

# Set y-axis to display in scientific notation with individual tick values
plt.gca().yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
plt.gca().yaxis.get_major_formatter().set_scientific(False)
plt.gca().yaxis.get_major_formatter().set_powerlimits((0,0))

# Rotate x-axis labels by 45 degrees
plt.xticks(rotation=90)

# Set y-axis to display numbers with commas
plt.gca().yaxis.set_major_formatter(FuncFormatter(lambda x, _: f'{int(x):,}'))

#add note for the text
#plt.text(3, 1, "Conformers: " + str(total_ligands), fontsize=12, color='black')
#plt.annotate("Total Atoms = " + str(total_atoms), xy=(0.29, -0.18), xycoords='axes fraction', fontsize=9, color='black')

plt.show()

# %%
# Create a bar plot for interaction count
plt.bar(df['ligand'], df['interaction_percentile'])
#plt.xlabel('Paper Ligand')
plt.ylabel('Percentile Ranking Against Control Set')
plt.title('Paper Ligands Percentile Ranking: Total Interactions')

plt.ylim(0,100)

# Set y-axis to display in scientific notation with individual tick values
plt.gca().yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
plt.gca().yaxis.get_major_formatter().set_scientific(False)
plt.gca().yaxis.get_major_formatter().set_powerlimits((0,0))

# Rotate x-axis labels by 45 degrees
plt.xticks(rotation=90)

# Set y-axis to display numbers with commas
plt.gca().yaxis.set_major_formatter(FuncFormatter(lambda x, _: f'{int(x):,}'))

#add note for the text
#plt.text(3, 1, "Conformers: " + str(total_ligands), fontsize=12, color='black')
#plt.annotate("Total Atoms = " + str(total_atoms), xy=(0.29, -0.18), xycoords='axes fraction', fontsize=9, color='black')

plt.show()

# %%
# Create a bar plot for real motif count
plt.bar(df['ligand'], df['real_motif_count_percentile'])
#plt.xlabel('Paper Ligand')
plt.ylabel('Percentile Ranking Against Control Set')
plt.title('Paper Ligands Percentile Ranking: Real Motif Count')

plt.ylim(0,100)

# Set y-axis to display in scientific notation with individual tick values
plt.gca().yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
plt.gca().yaxis.get_major_formatter().set_scientific(False)
plt.gca().yaxis.get_major_formatter().set_powerlimits((0,0))

# Rotate x-axis labels by 45 degrees
plt.xticks(rotation=90)

# Set y-axis to display numbers with commas
plt.gca().yaxis.set_major_formatter(FuncFormatter(lambda x, _: f'{int(x):,}'))

#add note for the text
#plt.text(3, 1, "Conformers: " + str(total_ligands), fontsize=12, color='black')
#plt.annotate("Total Atoms = " + str(total_atoms), xy=(0.29, -0.18), xycoords='axes fraction', fontsize=9, color='black')

plt.show()

# %%
# Create a bar plot for real motif ratio
plt.bar(df['ligand'], df['real_motif_ratio_percentile'])
#plt.xlabel('Paper Ligand')
plt.ylabel('Percentile Ranking Against Control Set')
plt.title('Paper Ligands Percentile Ranking: Real Motif Ratio')

plt.ylim(0,100)

# Set y-axis to display in scientific notation with individual tick values
plt.gca().yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
plt.gca().yaxis.get_major_formatter().set_scientific(False)
plt.gca().yaxis.get_major_formatter().set_powerlimits((0,0))

# Rotate x-axis labels by 45 degrees
plt.xticks(rotation=90)

# Set y-axis to display numbers with commas
plt.gca().yaxis.set_major_formatter(FuncFormatter(lambda x, _: f'{int(x):,}'))

#add note for the text
#plt.text(3, 1, "Conformers: " + str(total_ligands), fontsize=12, color='black')
#plt.annotate("Total Atoms = " + str(total_atoms), xy=(0.29, -0.18), xycoords='axes fraction', fontsize=9, color='black')

plt.show()
