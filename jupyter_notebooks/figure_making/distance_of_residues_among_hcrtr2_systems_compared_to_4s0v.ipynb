# 7xrr  0.320618  1.120261  0.847390    active
# 7l1v  1.734972  1.381900  1.777418  inactive
# 7l1u  1.380591  0.893546  1.488334  inactive
# 7sr8  1.553565  1.171378  1.762166  inactive
# 7sqo  1.854625  1.286931  1.837505  inactive

# %% [raw]
# print(df_sorted)

# %%
# Create a heatmap
plt.figure(figsize=(16, 8))
ax = sns.heatmap(
    df_sorted.drop(columns=["Group"]),  # Exclude the "Group" column from the heatmap
    annot=True,
    cmap="RdYlGn_r",
    fmt=".1f",
    annot_kws={"size": 8},
    cbar_kws={"shrink": 0.8,"orientation": "vertical", "location": "left"},
)

# Add horizontal lines to separate groups
group_counts = df_sorted["Group"].value_counts()
agonist_count = group_counts["active"]
antagonist_count = group_counts["inactive"]
ax.hlines(y=agonist_count, xmin=0, xmax=len(df_sorted.columns), color="black", linewidth=1.5)

# Add group labels
plt.text(len(df_sorted.columns) + 0.5, (agonist_count / 2) + 0.5, "Inactive", 
         fontsize=12, color="black", va="bottom", rotation=90)
plt.text(len(df_sorted.columns) + 0.5, (antagonist_count + (len(df_sorted) - antagonist_count) / 2) + 1.3, "Active", 
         fontsize=12, color="black", va="bottom", rotation=90)

#add heatmap key label
plt.text(-6.3, 8.7, "RMSD of Residue Against Corresponding 4S0V Residue (Å)", 
         fontsize=12, color="black", va="bottom", rotation=90)

# Add labels and title
plt.title("HCRTR2 Pocket Residue RMSD Against 4S0V", fontsize=16)
plt.xlabel("Residue Indices", fontsize=12)
plt.ylabel("Systems", fontsize=12)

# Show the heatmap
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(20, 8))  # Increase figure size to widen cells

sns.heatmap(df, annot=True, cmap="RdYlGn_r", fmt=".1f",annot_kws={"size": 10},cbar_kws={"shrink": 0.8})

# Add labels and title
plt.title("Heatmap Example")
plt.xlabel("Columns")
plt.ylabel("Rows")

# Display the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 3
#       1 plt.figure(figsize=(20, 8))  # Increase figure size to widen cells
# ----> 3 sns.heatmap(df, annot=True, cmap="RdYlGn_r", fmt=".1f",annot_kws={"size": 10},cbar_kws={"shrink": 0.8})
#       5 # Add labels and title
#       6 plt.title("Heatmap Example")
#
# File /share/apps/rc/software/Anaconda3/2023.07-2/lib/python3.11/site-packages/seaborn/matrix.py:446, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     365 """Plot rectangular data as a color-encoded matrix.
#     366
#     367 This is an Axes-level function and will draw the heatmap into the
#    (...)
#     443
#     444 """
#     445 # Initialize the plotter object
# --> 446 plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     447                       annot_kws, cbar, cbar_kws, xticklabels,
#     448                       yticklabels, mask)
#     450 # Add the pcolormesh kwargs here
#     451 kwargs["linewidths"] = linewidths
#
# File /share/apps/rc/software/Anaconda3/2023.07-2/lib/python3.11/site-packages/seaborn/matrix.py:163, in _HeatMapper.__init__(self, data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, cbar, cbar_kws, xticklabels, yticklabels, mask)
#     160 self.ylabel = ylabel if ylabel is not None else ""
#     162 # Determine good default values for the colormapping
# --> 163 self._determine_cmap_params(plot_data, vmin, vmax,
#     164                             cmap, center, robust)
#     166 # Sort out the annotations
#     167 if annot is None or annot is False:
#
# File /share/apps/rc/software/Anaconda3/2023.07-2/lib/python3.11/site-packages/seaborn/matrix.py:197, in _HeatMapper._determine_cmap_params(self, plot_data, vmin, vmax, cmap, center, robust)
#     194 """Use some heuristics to set good defaults for colorbar and range."""
#     196 # plot_data is a np.ma.array instance
# --> 197 calc_data = plot_data.astype(float).filled(np.nan)
#     198 if vmin is None:
#     199     if robust:
#
# ValueError: could not convert string to float: 'antagonist'
