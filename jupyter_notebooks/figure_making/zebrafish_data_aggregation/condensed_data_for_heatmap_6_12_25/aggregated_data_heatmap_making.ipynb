# %%
#imports
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#initial inport with numberofbouts
df = pd.read_csv("ari_data_numberofbouts_.csv", index_col=0)
df = df[['night_avg', 'day_avg']]

# %%
df
# Out:
#                                                     night_avg   day_avg
# drug
# /pi/summer.thyme-umw/behaviordata/ari_data_1_31...  -0.223328 -0.448011
# /pi/summer.thyme-umw/behaviordata/ari_data_1_31...  -0.542890 -0.375298
# /pi/summer.thyme-umw/behaviordata/ari_data_3_11...   0.224574 -0.296717
# /pi/summer.thyme-umw/behaviordata/ari_data_3_11...   1.173500  1.771084
# /pi/summer.thyme-umw/behaviordata/ari_data_4_11...   0.372903  0.465083
# ...                                                       ...       ...
# /pi/summer.thyme-umw/behaviordata/ari_data_6_6_...   0.391943  0.380048
# /pi/summer.thyme-umw/behaviordata/ari_data_6_6_...   0.292277  0.189917
# /pi/summer.thyme-umw/behaviordata/ari_data_6_6_...   0.371303  0.370451
# /pi/summer.thyme-umw/behaviordata/ari_data_6_6_...  -0.331183 -0.185879
# /pi/summer.thyme-umw/behaviordata/ari_data_6_6_...   0.161419  0.110967
#
# [64 rows x 2 columns]

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(df, annot=True, cmap="coolwarm")  # You can change colormap (e.g., 'coolwarm', 'RdBu', etc.)
plt.title("Number of Bouts (dpix)")
plt.ylabel("Drugs")
plt.xlabel("Metrics")
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_1458527/1681508904.py:6: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
