# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import ScalarFormatter
from matplotlib.ticker import FuncFormatter
#https://stackoverflow.com/questions/32085531/importing-a-csv-file-into-python-to-make-scatterplots-and-histograms

# %%
pd.set_option('display.max_columns', None)
#pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)

# %%
df  = pd.read_csv("/data/project/thymelab/october_2024_hcrtr2_discovery_results/old_antagonist_data_to_keep/all_antagonist_data.csv")

# %%
#this crashes with how big the dataframe is with the open options
df
# Out:
#                                                                                                                 file  \
# 0                                  /scratch/abgvg9/discovery_results/antagonists/0/placements/7l1u_receptor_only.pdb
# 1         /scratch/abgvg9/discovery_results/antagonists/10000/placements/4s0v_receptor_only_PV-005593546679_4_11.pdb
# 2          /scratch/abgvg9/discovery_results/antagonists/10000/placements/4s0v_receptor_only_PV-005593443896_6_0.pdb
# 3          /scratch/abgvg9/discovery_results/antagonists/10000/placements/4s0v_receptor_only_PV-005593387485_3_3.pdb
# 4          /scratch/abgvg9/discovery_results/antagonists/10000/placements/4s0v_receptor_only_PV-005593656674_1_0.pdb
# ...                                                                                                              ...
# 14532852   /scratch/abgvg9/discovery_results/antagonists/9999/placements/4s0v_receptor_only_PV-005593027748_12_4.pdb
# 14532853   /scratch/abgvg9/discovery_results/antagonists/9999/placements/4s0v_receptor_only_PV-005593315668_10_0.pdb
# 14532854    /scratch/abgvg9/discovery_results/antagonists/9999/placements/4s0v_receptor_only_PV-005592961713_1_1.pdb
# 14532855    /scratch/abgvg9/discovery_results/antagonists/9999/placements/4s0v_receptor_only_PV-005592726881_8_0.pdb
# 14532856                           /scratch/abgvg9/discovery_results/antagonists/9/placements/7l1u_receptor_only.pdb
#
#                 ddg  total_motifs  significant_motifs  real_motif_ratio  \
# 0          0.000000           0.0                 0.0          0.000000
# 1         -9.861034           7.0                 2.0          0.142857
# 2         -9.037033           6.0                 2.0          0.166667
# 3        -12.278551           8.0                 5.0          0.125000
# 4        -10.394492          11.0                 3.0          0.090909
# ...             ...           ...                 ...               ...
# 14532852 -11.174830           9.0                 3.0          0.222222
# 14532853  -9.410341           7.0                 1.0          0.142857
# 14532854 -13.202574           7.0                 5.0          0.142857
# 14532855 -13.092912           7.0                 2.0          0.142857
# 14532856   0.000000           0.0                 0.0          0.000000
#
#           hbond_motif_count  hbond_motif_energy_sum  \
# 0                         0                0.000000
# 1                         1               -0.258671
# 2                         1               -0.223285
# 3                         1               -0.540236
# 4                         0                0.000000
# ...                     ...                     ...
# 14532852                  2               -1.376323
# 14532853                  1               -0.841888
# 14532854                  1               -0.672649
# 14532855                  0                0.000000
# 14532856                  0                0.000000
#
#           closest_autodock_recovery_rmsd  closest_autodock_recovery_ddg  \
# 0                                    100                              0
# 1                                    100                              0
# 2                                    100                              0
# 3                                    100                              0
# 4                                    100                              0
# ...                                  ...                            ...
# 14532852                             100                              0
# 14532853                             100                              0
# 14532854                             100                              0
# 14532855                             100                              0
# 14532856                             100                              0
#
#           strain_energy       total
# 0                     0  100.000000
# 1                     0  100.023152
# 2                     0   99.906349
# 3                     0  101.306213
# 4                     0  103.696417
# ...                 ...         ...
# 14532852              0  101.671069
# 14532853              0   98.890628
# 14532854              0   99.267634
# 14532855              0   96.049945
# 14532856              0  100.000000
#
# [14532857 rows x 11 columns]

# %%
#get rid of weird 0 ddg values
df = df[df['ddg'] != 0]

# %%
len(df)
# Out:
# 14521723

# %%
#ddg
x = df['ddg']
#set labels and title
plt.xlabel('ddg')
plt.ylabel('Frequency')
plt.title('ddg')
#create 30 bin 1D hsitogram
plt.hist(x, bins=10, color='blue')
#set grid
plt.grid(True)
#show plot
plt.show()

# %%
#hbond
x = df['hbond_motif_count']
#set labels and title
plt.xlabel('Hydrogen Bond Count')
plt.ylabel('Frequency')
plt.title('Hydrogen Bonds Per System')

bin_edges = np.arange(-0.5, 5, 1)

# Plot histogram
#plt.hist(x, bins=bin_edges, edgecolor='black')

#create 30 bin 1D hsitogram
plt.hist(x, bins=bin_edges, color='blue', align='mid', width = 1, edgecolor='black')
#set grid
#plt.grid(True)

# Set y-axis to display in scientific notation with individual tick values
plt.gca().yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
plt.gca().yaxis.get_major_formatter().set_scientific(False)
plt.gca().yaxis.get_major_formatter().set_powerlimits((0,0))
# Set y-axis to display numbers with commas
plt.gca().yaxis.set_major_formatter(FuncFormatter(lambda x, _: f'{int(x):,}'))
#set y scale to log
plt.yscale('log')

#show plot
plt.show()

# %%
#ddg
x = df['real_motif_ratio']
#set labels and title
plt.xlabel('real_motif_ratio')
plt.ylabel('Frequency')
plt.title('real_motif_ratio')
#create 30 bin 1D hsitogram
plt.hist(x, bins=4, color='blue')
#set grid
plt.grid(True)
#show plot
plt.show()

# %%
#make dataframe with only rosetta hbond count of 3
df_3_hbonds = df[df['hbond_motif_count'] >= 3]
df_3_hbonds = df_3_hbonds.sort_values(by='ddg')

# %%
df_3_hbonds
# Out:
#                                                                                                                 file  \
# 591605    /scratch/abgvg9/discovery_results/antagonists/10519/placements/4s0v_receptor_only_PV-006025420297_10_0.pdb
# 3026559         /scratch/abgvg9/discovery_results/antagonists/1467/placements/4s0v_receptor_only_Z2650638950_3_9.pdb
# 6200328    /scratch/abgvg9/discovery_results/antagonists/3643/placements/4s0v_receptor_only_PV-005249995096_11_0.pdb
# 3193681    /scratch/abgvg9/discovery_results/antagonists/1557/placements/4s0v_receptor_only_PV-003921628028_13_7.pdb
# 11793969    /scratch/abgvg9/discovery_results/antagonists/7824/placements/4s0v_receptor_only_PV-005046774983_3_4.pdb
# ...                                                                                                              ...
# 2805786        /scratch/abgvg9/discovery_results/antagonists/1396/placements/4s0v_receptor_only_Z3861080439_10_0.pdb
# 4020620    /scratch/abgvg9/discovery_results/antagonists/2186/placements/4s0v_receptor_only_PV-003585390046_14_5.pdb
# 6005187     /scratch/abgvg9/discovery_results/antagonists/3498/placements/4s0v_receptor_only_PV-005072253249_7_0.pdb
# 4357811     /scratch/abgvg9/discovery_results/antagonists/2451/placements/4s0v_receptor_only_PV-006373997884_8_0.pdb
# 8858303    /scratch/abgvg9/discovery_results/antagonists/5719/placements/4s0v_receptor_only_PV-006035470194_13_2.pdb
#
#                 ddg  total_motifs  significant_motifs  real_motif_ratio  \
# 591605   -22.912940          10.0                 1.0          0.100000
# 3026559  -22.561287          11.0                 5.0          0.181818
# 6200328  -22.542003          12.0                 6.0          0.083333
# 3193681  -22.261472           8.0                 4.0          0.125000
# 11793969 -22.249342          10.0                 6.0          0.200000
# ...             ...           ...                 ...               ...
# 2805786   -9.000068           7.0                 1.0          0.142857
# 4020620   -9.000041          11.0                 3.0          0.090909
# 6005187   -9.000022           8.0                 3.0          0.125000
# 4357811   -9.000019          10.0                 2.0          0.100000
# 8858303   -9.000016           9.0                 3.0          0.111111
#
#           hbond_motif_count  hbond_motif_energy_sum  \
# 591605                    3               -3.340291
# 3026559                   3               -1.701871
# 6200328                   3               -1.894506
# 3193681                   3               -4.714554
# 11793969                  3               -2.815362
# ...                     ...                     ...
# 2805786                   3               -1.525792
# 4020620                   3               -1.805830
# 6005187                   3               -1.402166
# 4357811                   3               -1.558998
# 8858303                   3               -1.585511
#
#           closest_autodock_recovery_rmsd  closest_autodock_recovery_ddg  \
# 591605                               100                              0
# 3026559                              100                              0
# 6200328                              100                              0
# 3193681                              100                              0
# 11793969                             100                              0
# ...                                  ...                            ...
# 2805786                              100                              0
# 4020620                              100                              0
# 6005187                              100                              0
# 4357811                              100                              0
# 8858303                              100                              0
#
#           strain_energy       total
# 591605                0   87.846769
# 3026559               0   94.918660
# 6200328               0   96.646824
# 3193681               0   88.148974
# 11793969              0   94.135296
# ...                 ...         ...
# 2805786               0  100.616997
# 4020620               0  106.285038
# 6005187               0  103.722812
# 4357811               0  104.540983
# 8858303               0  104.525584
#
# [270619 rows x 11 columns]

# %%
len(df_3_hbonds)
# Out:
# 270619

# %%
#ddg
x = df['ddg']
#set labels and title
plt.xlabel('ddG (REU)')
plt.ylabel('Frequency')
plt.title('Placement ddG')
#create 30 bin 1D hsitogram
plt.hist(x, bins=30, color='blue')
#set grid
plt.grid(True)
#show plot
plt.show()

# %%
#make the low ddg dataframe and csv for antagonists
df_16 = df[df['ddg'] < -16]
df_16_real_quarter = df_16[df_16['real_motif_ratio'] >= 0.25]

# %%
len(df_16_real_quarter)
# Out:
# 7669

# %%
df_16_real_quarter.to_csv('/scratch/abgvg9/discovery_results/antagonists/12M_-16_ddg_quarter_real.csv', index=False)

# %%
#make the half real motif dataframe and csv
#to be consistent with agonist set, no restriction on rosetta hbond count, since that was ultimately ditched
df_half_real = df[df['real_motif_ratio'] >= 0.5]

# %%
len(df_half_real)
# Out:
# 7257

# %%
df_half_real.to_csv('/scratch/abgvg9/discovery_results/antagonists/12M_list_filtered_half_real_2_hbonds.csv', index=False)
